# %%
import tensorflow as tf

# Check GPU availability
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Using GPU: ", tf.test.gpu_device_name())
# Out:
# Num GPUs Available:  1
# Using GPU:  /device:GPU:0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install requirements
# !apt install unrar
# !pip install pyunpack patool

# Import libraries
from pyunpack import Archive
import os

# Define paths
rar_path = '/content/drive/MyDrive/Colab Dataset/data.rar'
extract_path = '/content/dataset'

# Create the extraction directory
os.makedirs(extract_path, exist_ok=True)

# Extract the .rar file
Archive(rar_path).extractall(extract_path)
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 7.4 MB/s eta 0:00:00
# ...

# %%
# =========================================================
# 🧩 STEP 1: SETUP YOLOv5 ENVIRONMENT
# =========================================================
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import clear_output
clear_output()
print("✅ YOLOv5 installed successfully!")
print("🔥 GPU available:", torch.cuda.is_available())
# Out:
# ✅ YOLOv5 installed successfully!
# 🔥 GPU available: True

# %%
dataset_path = '/content/dataset/data/Detection'

# %%
# =========================================================
# 🧾 STEP 3: CREATE data.yaml FILE
# =========================================================
# YOLOv5 needs a small YAML file describing dataset paths + class names
import yaml

data_yaml = {
'train': '/content/dataset/data/Detection/train/images',
'val': '/content/dataset/data/Detection/validation/images',
'test': '/content/dataset/data/Detection/test/images',
'nc': 1,
'names': ['Taka']
}

with open('data.yaml', 'w') as f:
    yaml.dump(data_yaml, f, default_flow_style=False)

# !cat data.yaml

# %%
os.environ['WANDB_MODE'] = 'disabled'
# !python train.py --img 640 --batch 16 --epochs 50 --data data.yaml --weights yolov5s.pt --project Taka_Detection --name exp1 --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#       34/49      4.43G    0.01606   0.007468          0         36        640:  66% 105/160 [00:29<00:13,  3.98it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.43G    0.01607   0.007477          0         40        640:  66% 106/160 [00:29<00:13,  4.00it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.43G     0.0161   0.007472          0         32        640:  67% 107/160 [00:29<00:13,  3.81it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# =========================================================
# 📸 STEP 7: DISPLAY DETECTED IMAGE
# =========================================================
import glob
from IPython.display import Image, display

for image_path in glob.glob('runs/detect/exp/*.jpg'):
    display(Image(filename=image_path))

# %%
# =========================================================
# 🧠 STEP 6: TEST MODEL ON SAMPLE IMAGE
# =========================================================
# Place your test image in /content/test_image.jpg or provide path below

# !python detect.py --weights /content/yolov5/Taka_Detection/exp13/weights/best.pt --img 640 --conf 0.25 --source /content/IMG_8003_JPG.rf.c4d5ecb43069c6cc86c5924c63ddc7ce.jpg --save-txt --save-conf
# Out:
# detect: weights=['/content/yolov5/Taka_Detection/exp13/weights/best.pt'], source=/content/IMG_8003_JPG.rf.c4d5ecb43069c6cc86c5924c63ddc7ce.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-441-g15c0127a Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/IMG_8003_JPG.rf.c4d5ecb43069c6cc86c5924c63ddc7ce.jpg: 640x640 1 Taka, 11.4ms
# Speed: 0.6ms pre-process, 11.4ms inference, 116.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
# ...
